# %% [markdown]
# ### Import pacchetti

# %%
gdrive = True

# %%
from psutil import virtual_memory
def check_gpu_and_ram():
    print('******************************************************************************')
    print('---------------------------------  GPU  --------------------------------------')
    print('******************************************************************************')
    gpu_info = !nvidia-smi
    gpu_info = '\n'.join(gpu_info)
    if gpu_info.find('failed') >= 0:
        print('Select the Runtime > "Change runtime type" menu to enable a GPU accelerator, ')
        print('and then re-execute this cell.')
    else:
        print(gpu_info)
    print('\n')
    print('******************************************************************************')

    print('---------------------------------  RAM  --------------------------------------')

    print('******************************************************************************')

    ram_gb = virtual_memory().total / 1e9
    print('Your runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

    if ram_gb < 20:
        print('To enable a high-RAM runtime, select the Runtime > "Change runtime type"')
        print('menu, and then select High-RAM in the Runtime shape dropdown. Then, ')
        print('re-execute this cell.')
    else:
        print('You are using a high-RAM runtime!')

# %%
import sys
import os
if gdrive:
    from google.colab import drive
    drive.mount('/content/gdrive')
    # %tensorflow_version 1.x
    sys.path.append('/content/gdrive/My Drive/Tesi/src/')
    check_gpu_and_ram()
# Out:
# Mounted at /content/gdrive
# TensorFlow 1.x selected.
# ******************************************************************************
# ---------------------------------  GPU  --------------------------------------
# ******************************************************************************
# Sat Feb 13 10:25:58 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.39       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla V100-SXM2...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   33C    P0    24W / 300W |      0MiB / 16160MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
#
#
# ******************************************************************************
# ---------------------------------  RAM  --------------------------------------
# ******************************************************************************
# Your runtime has 27.4 gigabytes of available RAM
#
# You are using a high-RAM runtime!

# %%
import warnings
warnings.filterwarnings('ignore')
import numpy as np
import tensorflow as tf
import pickle
import time
from dataset import *
from training_ops import *
from params import *
from models import get_model
# Out:
# Using TensorFlow backend.

# %%
print(tf.__version__)
# Out:
# 1.15.2

# %% [markdown]
# ### Import dati e set di alcuni parametri

# %%
multispeaker = False
if multispeaker:
    sample_training = True
else:
    sample_training = False
architecture_params, opt_params = read_params('gionet2')
data_path = read_datapath(multispeaker = multispeaker, gdrive = gdrive)
logdir = get_logdir(data_path, opt_params, architecture_params)

# %%
# %%time
X_train, Y_train, X_val, Y_val = read_data(data_path, sample_training = sample_training)
n_train, n_validation = X_train.shape[0], X_val.shape[0]
print('number of training examples: {}'.format(n_train))
print('number of validation examples: {}'.format(n_validation))
# Out:
# number of training examples: 6656
# number of validation examples: 768
# CPU times: user 123 ms, sys: 376 ms, total: 498 ms
# Wall time: 4.23 s

# %%
checkpoint_root = os.path.join(logdir, 'model.ckpt')
gpu_options = tf.GPUOptions(allow_growth=True)
sess = tf.Session(config=tf.ConfigProto(gpu_options=gpu_options, allow_soft_placement=True, log_device_placement=True))
if os.path.isdir(logdir):
    print('Model loading...')
    checkpoint = read_latest_checkpoint(logdir, gdrive)
    meta = checkpoint + '.meta'
    saver = tf.train.import_meta_graph(meta)
    g = tf.get_default_graph()
    saver.restore(sess, checkpoint)
    X_lr, Y, alpha = tf.get_collection('inputs')[0:3]
    inputs = (X_lr, Y, alpha)
    predictions = tf.get_collection('preds')[0]
    loss = create_objective(Y, predictions)
    train_op = tf.get_collection('train_op')
    with open(os.path.join(logdir, 'train_metrics.pickle'), 'rb') as handle:
        train_metrics = pickle.load(handle)
    epochs_completed = get_epochs_completed(checkpoint)
else:
    print('Model creation...')
    checkpoint = logdir
    n_dim, n_chan = 8192, 1
    X_lr = tf.placeholder(tf.float32, shape=(None, n_dim, 1), name='X_lr') #(None, n_dim, 1)
    Y = tf.placeholder(tf.float32, shape=(None, None, 1), name='Y') #(None, n_dim, 1)
    alpha = tf.placeholder(tf.float32, shape=(), name='alpha') # weight multiplier
    tf.add_to_collection('inputs', X_lr)
    tf.add_to_collection('inputs', Y)
    tf.add_to_collection('inputs', alpha)
    inputs = (X_lr, Y, alpha)
    predictions = get_model(X_lr, architecture_params)
    tf.add_to_collection('preds', predictions)
    loss = create_objective(Y, predictions)
    params = get_params()
    optimizer = create_optimzier(opt_params)
    grads = create_gradients(loss, params, optimizer)
    with tf.name_scope('optimizer'):
        train_op = create_updates(params, grads, alpha, optimizer)
    init = tf.global_variables_initializer()
    sess.run(init)
    tf.add_to_collection('train_op', train_op)
    saver = tf.train.Saver()
    train_metrics = {}
    epochs_completed = 0
print("The total number of parameters in the model is: " + str(count_parameters()))
train_data = DataSet(X_train, Y_train, epochs_completed = epochs_completed)
validation_data = DataSet(X_val, Y_val, epochs_completed = epochs_completed)
del X_train
del Y_train
del X_val
del Y_val
print('Model is ready for training phase. The total number of epochs completed is {}'.format(epochs_completed))
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:GPU:0 -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:00:04.0, compute capability: 7.0
#
# Model loading...
# INFO:tensorflow:Restoring parameters from /content/gdrive/My Drive/Tesi/processedData/speaker1/train&validation/model_ckpt/gionet2.lr0.000030dec.4.g3.b128/model_ckpt-91
# WARNING:tensorflow:From /content/gdrive/My Drive/Tesi/src/training_ops.py:144: The name tf.log is deprecated. Please use tf.math.log instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Tesi/src/training_ops.py:150: The name tf.add_to_collection is deprecated. Please use tf.compat.v1.add_to_collection instead.
#
# WARNING:tensorflow:From /content/gdrive/My Drive/Tesi/src/training_ops.py:129: The name tf.trainable_variables is deprecated. Please use tf.compat.v1.trainable_variables instead.
#
# The total number of parameters in the model is: 23485829
# Model is ready for training phase. The total number of epochs completed is 91

# %% [markdown]
# ### Fit del modello

# %%
batch_size = opt_params['batch_size']
if multispeaker:
    n_steps = opt_params['tot_steps']
    steps_for_interruption = opt_params['steps_for_interruption']
    n_epochs = calc_epochs_from_n_steps(n_steps, batch_size, n_train)
    epochs_for_interruption = calc_epochs_from_n_steps(steps_for_interruption, batch_size, n_train)
else:
    n_epochs = n_epochs_in_multispeaker_task(logdir) #:= number of epochs performed for this model in multispeaker task 
    epochs_for_interruption = None
n_steps_for_1_validation_epoch = int(n_validation/128)
print('n_epochs: {}'.format(n_epochs))
print('epochs_for_interruption: {}'.format(epochs_for_interruption))
# Out:
# n_epochs: 246
# epochs_for_interruption: None

# %%
current_epoch = train_data._epochs_completed
alpha = 1.0
losses_on_batch = []
snr_on_batch = []
epoch_start_time = time.time()
if len(train_metrics)>0:
    interrupt = early_stopping(train_metrics, epochs_for_interruption, multispeaker = multispeaker)
else:
    interrupt = False
n_iters = 0
while (train_data._epochs_completed < n_epochs)&(interrupt==False):
    batch = train_data.next_batch(batch_size)
    feed_dict = load_batch(inputs, batch, alpha) #mi serve sia per calcolare la loss in training che per fare l'update dei parametri
    feed_dict_not_train = load_batch(inputs, batch, alpha, train=False)
    tr_objective = train(feed_dict, train_op, loss, sess) #fa l'update dei parametri e restituisce il valore della loss
    losses_on_batch.append(tr_objective)
    snr_on_batch.append(sess.run(tf.get_collection(key='snr_on_batch'), feed_dict=feed_dict_not_train)[0])
    if train_data._epochs_completed > current_epoch:
        l2_training = np.mean(losses_on_batch, dtype = np.float32)
        snr_training = np.mean(snr_on_batch, dtype = np.float32)
        l2_v = []
        snr_v = []
        for b in range(n_steps_for_1_validation_epoch):
            v_batch = validation_data.next_batch(batch_size)
            feed_dict_validation = load_batch(inputs, v_batch, alpha, train=False)
            l2_v.append(sess.run(loss, feed_dict=feed_dict_validation))
            snr_v.append(sess.run(tf.get_collection(key='snr_on_batch'), feed_dict=feed_dict_validation)[0])
        l2_validation = np.mean(l2_v, dtype = np.float32)
        snr_validation = np.mean(snr_v, dtype = np.float32)
        train_metrics[current_epoch] = {'l2_training': l2_training,
                                        'snr_training': snr_training,
                                        'l2_validation': l2_validation,
                                        'snr_validation': snr_validation
                                       }
        epoch_end_time = time.time()
        tot_time_s = epoch_end_time - epoch_start_time
        print_epoch_with_time(tot_time_s, train_data._epochs_completed)
        print_metrics(l2_training, snr_training, l2_validation, snr_validation)
        save_model_phase(sess, logdir, train_data._epochs_completed, train_metrics, saver, multispeaker = multispeaker) #save the model and the dictionary with metrics
        save_architecture_opt_params(logdir, architecture_params, opt_params)
        interrupt = early_stopping(train_metrics, epochs_for_interruption, multispeaker = multispeaker)
        losses_on_batch = []
        snr_on_batch = []
        current_epoch = train_data._epochs_completed
        epoch_start_time = time.time()
        n_iters +=1
# Out:
# ------- EPOCH 92 RESULTS ------- (trained in 1.88 minutes. Current time: 11:28)
# l2 (loss) on training is 0.0058752126060426235
# snr on training is 16.577205657958984
# l2 (loss) on validation is 0.005062172655016184
# snr on validation is 17.519365310668945
#
# ------- EPOCH 93 RESULTS ------- (trained in 1.53 minutes. Current time: 11:30)
# l2 (loss) on training is 0.00588283920660615
# snr on training is 16.56191062927246
# l2 (loss) on validation is 0.005043835379183292
# snr on validation is 17.54297637939453
#
# ------- EPOCH 94 RESULTS ------- (trained in 1.55 minutes. Current time: 11:31)
# l2 (loss) on training is 0.0058833155781030655
# snr on training is 16.57038116455078
# l2 (loss) on validation is 0.005060721654444933
# snr on validation is 17.518857955932617
#
# ------- EPOCH 95 RESULTS ------- (trained in 1.55 minutes. Current time: 11:33)
# l2 (loss) on training is 0.005884953774511814
# snr on training is 16.584732055664062
# l2 (loss) on validation is 0.005073168780654669
# snr on validation is 17.50200843811035
#
# ------- EPOCH 96 RESULTS ------- (trained in 1.54 minutes. Current time: 11:35)
# l2 (loss) on training is 0.00585547648370266
# snr on training is 16.55848503112793
# l2 (loss) on validation is 0.005070710089057684
# snr on validation is 17.505550384521484
#
# ------- EPOCH 97 RESULTS ------- (trained in 1.57 minutes. Current time: 11:36)
# l2 (loss) on training is 0.005876548588275909
# snr on training is 16.61155891418457
# l2 (loss) on validation is 0.005060714203864336
# snr on validation is 17.520286560058594
#
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.6/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ------- EPOCH 98 RESULTS ------- (trained in 1.55 minutes. Current time: 11:38)
# l2 (loss) on training is 0.005857187323272228
# snr on training is 16.566089630126953
# l2 (loss) on validation is 0.0050710332579910755
# snr on validation is 17.50358772277832
#
# ------- EPOCH 99 RESULTS ------- (trained in 1.54 minutes. Current time: 11:39)
# l2 (loss) on training is 0.005885367747396231
# snr on training is 16.58580780029297
# l2 (loss) on validation is 0.005080667790025473
# snr on validation is 17.4930419921875
#
# ------- EPOCH 100 RESULTS ------- (trained in 1.52 minutes. Current time: 11:41)
# l2 (loss) on training is 0.0058850133791565895
# snr on training is 16.594820022583008
# l2 (loss) on validation is 0.005088429898023605
# snr on validation is 17.48052215576172
#
# ------- EPOCH 101 RESULTS ------- (trained in 1.5 minutes. Current time: 11:42)
# l2 (loss) on training is 0.005853724200278521
# snr on training is 16.55712890625
# l2 (loss) on validation is 0.005073531065136194
# snr on validation is 17.502155303955078
#
# ------- EPOCH 102 RESULTS ------- (trained in 1.52 minutes. Current time: 11:44)
# l2 (loss) on training is 0.005860038101673126
# snr on training is 16.593870162963867
# l2 (loss) on validation is 0.0050532035529613495
# snr on validation is 17.52888298034668
#
# ------- EPOCH 103 RESULTS ------- (trained in 1.51 minutes. Current time: 11:45)
# l2 (loss) on training is 0.005886687897145748
# snr on training is 16.572675704956055
# l2 (loss) on validation is 0.005078708287328482
# snr on validation is 17.493310928344727
#
# ------- EPOCH 104 RESULTS ------- (trained in 1.52 minutes. Current time: 11:47)
# l2 (loss) on training is 0.0058616772294044495
# snr on training is 16.60543441772461
# l2 (loss) on validation is 0.005089166108518839
# snr on validation is 17.480470657348633
#
# ------- EPOCH 105 RESULTS ------- (trained in 1.51 minutes. Current time: 11:48)
# l2 (loss) on training is 0.005849095061421394
# snr on training is 16.572498321533203
# l2 (loss) on validation is 0.005066773388534784
# snr on validation is 17.50752830505371
#
# ------- EPOCH 106 RESULTS ------- (trained in 1.5 minutes. Current time: 11:50)
# l2 (loss) on training is 0.005877576302736998
# snr on training is 16.607704162597656
# l2 (loss) on validation is 0.005052974913269281
# snr on validation is 17.53146743774414
#
# ------- EPOCH 107 RESULTS ------- (trained in 1.51 minutes. Current time: 11:52)
# l2 (loss) on training is 0.005840381141752005
# snr on training is 16.600074768066406
# l2 (loss) on validation is 0.005052030086517334
# snr on validation is 17.53048324584961
#
# ------- EPOCH 108 RESULTS ------- (trained in 1.51 minutes. Current time: 11:53)
# l2 (loss) on training is 0.005864315200597048
# snr on training is 16.594221115112305
# l2 (loss) on validation is 0.005055158399045467
# snr on validation is 17.5284481048584
#
# ------- EPOCH 109 RESULTS ------- (trained in 1.5 minutes. Current time: 11:55)
# l2 (loss) on training is 0.005845985375344753
# snr on training is 16.602933883666992
# l2 (loss) on validation is 0.005058839451521635
# snr on validation is 17.525774002075195
#
# ------- EPOCH 110 RESULTS ------- (trained in 1.5 minutes. Current time: 11:56)
# l2 (loss) on training is 0.0058416808024048805
# snr on training is 16.61945915222168
# l2 (loss) on validation is 0.005061544943600893
# snr on validation is 17.518808364868164
#
# ------- EPOCH 111 RESULTS ------- (trained in 1.51 minutes. Current time: 11:58)
# l2 (loss) on training is 0.005831004120409489
# snr on training is 16.599613189697266
# l2 (loss) on validation is 0.0050545744597911835
# snr on validation is 17.52550506591797
#
# ------- EPOCH 112 RESULTS ------- (trained in 1.5 minutes. Current time: 11:59)
# l2 (loss) on training is 0.005864862818270922
# snr on training is 16.62078857421875
# l2 (loss) on validation is 0.005054348614066839
# snr on validation is 17.524709701538086
#
# ------- EPOCH 113 RESULTS ------- (trained in 1.51 minutes. Current time: 12:01)
# l2 (loss) on training is 0.005827972665429115
# snr on training is 16.59516143798828
# l2 (loss) on validation is 0.005056906025856733
# snr on validation is 17.523401260375977
#
# ------- EPOCH 114 RESULTS ------- (trained in 1.51 minutes. Current time: 12:02)
# l2 (loss) on training is 0.005851306486874819
# snr on training is 16.626367568969727
# l2 (loss) on validation is 0.005061011761426926
# snr on validation is 17.519622802734375
#
# ------- EPOCH 115 RESULTS ------- (trained in 1.5 minutes. Current time: 12:04)
# l2 (loss) on training is 0.005843703635036945
# snr on training is 16.601484298706055
# l2 (loss) on validation is 0.0050592608749866486
# snr on validation is 17.522214889526367
#
# ------- EPOCH 116 RESULTS ------- (trained in 1.5 minutes. Current time: 12:05)
# l2 (loss) on training is 0.005828531924635172
# snr on training is 16.621736526489258
# l2 (loss) on validation is 0.0050596692599356174
# snr on validation is 17.52183723449707
#
# ------- EPOCH 117 RESULTS ------- (trained in 1.5 minutes. Current time: 12:07)
# l2 (loss) on training is 0.005842330865561962
# snr on training is 16.598310470581055
# l2 (loss) on validation is 0.005053461994975805
# snr on validation is 17.52922248840332
#
# ------- EPOCH 118 RESULTS ------- (trained in 1.5 minutes. Current time: 12:08)
# l2 (loss) on training is 0.005861778277903795
# snr on training is 16.626338958740234
# l2 (loss) on validation is 0.005069334991276264
# snr on validation is 17.506303787231445
#
# ------- EPOCH 119 RESULTS ------- (trained in 1.5 minutes. Current time: 12:10)
# l2 (loss) on training is 0.0058422088623046875
# snr on training is 16.609941482543945
# l2 (loss) on validation is 0.005060479510575533
# snr on validation is 17.5189151763916
#
# ------- EPOCH 120 RESULTS ------- (trained in 1.5 minutes. Current time: 12:11)
# l2 (loss) on training is 0.00584560539573431
# snr on training is 16.621322631835938
# l2 (loss) on validation is 0.0050642057321965694
# snr on validation is 17.5137882232666
#
# ------- EPOCH 121 RESULTS ------- (trained in 1.5 minutes. Current time: 12:13)
# l2 (loss) on training is 0.005836076568812132
# snr on training is 16.616554260253906
# l2 (loss) on validation is 0.00505412183701992
# snr on validation is 17.526119232177734
#
# ------- EPOCH 122 RESULTS ------- (trained in 1.5 minutes. Current time: 12:14)
# l2 (loss) on training is 0.005815036594867706
# snr on training is 16.61917495727539
# l2 (loss) on validation is 0.005057044792920351
# snr on validation is 17.523212432861328
#
# ------- EPOCH 123 RESULTS ------- (trained in 1.5 minutes. Current time: 12:16)
# l2 (loss) on training is 0.00582518707960844
# snr on training is 16.644418716430664
# l2 (loss) on validation is 0.005060213152319193
# snr on validation is 17.518810272216797
#
# ------- EPOCH 124 RESULTS ------- (trained in 1.51 minutes. Current time: 12:18)
# l2 (loss) on training is 0.005835553165525198
# snr on training is 16.616107940673828
# l2 (loss) on validation is 0.005062686745077372
# snr on validation is 17.516340255737305
#
# ------- EPOCH 125 RESULTS ------- (trained in 1.5 minutes. Current time: 12:19)
# l2 (loss) on training is 0.005806541070342064
# snr on training is 16.615447998046875
# l2 (loss) on validation is 0.005062253680080175
# snr on validation is 17.518661499023438
#
# ------- EPOCH 126 RESULTS ------- (trained in 1.49 minutes. Current time: 12:21)
# l2 (loss) on training is 0.005840586964040995
# snr on training is 16.653474807739258
# l2 (loss) on validation is 0.005050250794738531
# snr on validation is 17.53288459777832
#
# ------- EPOCH 127 RESULTS ------- (trained in 1.5 minutes. Current time: 12:22)
# l2 (loss) on training is 0.00581849180161953
# snr on training is 16.62091064453125
# l2 (loss) on validation is 0.0050533306784927845
# snr on validation is 17.528146743774414
#
# ------- EPOCH 128 RESULTS ------- (trained in 1.51 minutes. Current time: 12:24)
# l2 (loss) on training is 0.005833498202264309
# snr on training is 16.63736915588379
# l2 (loss) on validation is 0.005053721833974123
# snr on validation is 17.528573989868164
#
# ------- EPOCH 129 RESULTS ------- (trained in 1.51 minutes. Current time: 12:25)
# l2 (loss) on training is 0.00581102492287755
# snr on training is 16.63074493408203
# l2 (loss) on validation is 0.005060732830315828
# snr on validation is 17.519744873046875
#
# ------- EPOCH 130 RESULTS ------- (trained in 1.5 minutes. Current time: 12:27)
# l2 (loss) on training is 0.005825933534651995
# snr on training is 16.616973876953125
# l2 (loss) on validation is 0.005076498258858919
# snr on validation is 17.495450973510742
#
# ------- EPOCH 131 RESULTS ------- (trained in 1.51 minutes. Current time: 12:28)
# l2 (loss) on training is 0.0058484068140387535
# snr on training is 16.61327362060547
# l2 (loss) on validation is 0.005043427925556898
# snr on validation is 17.538671493530273
#
# ------- EPOCH 132 RESULTS ------- (trained in 1.5 minutes. Current time: 12:30)
# l2 (loss) on training is 0.005818056408315897
# snr on training is 16.65906524658203
# l2 (loss) on validation is 0.005054015666246414
# snr on validation is 17.52251434326172
#
# ------- EPOCH 133 RESULTS ------- (trained in 1.5 minutes. Current time: 12:31)
# l2 (loss) on training is 0.005827354267239571
# snr on training is 16.630474090576172
# l2 (loss) on validation is 0.005059587303549051
# snr on validation is 17.517236709594727
#
# ------- EPOCH 134 RESULTS ------- (trained in 1.5 minutes. Current time: 12:33)
# l2 (loss) on training is 0.005803202744573355
# snr on training is 16.630741119384766
# l2 (loss) on validation is 0.005054174456745386
# snr on validation is 17.526565551757812
#
# ------- EPOCH 135 RESULTS ------- (trained in 1.51 minutes. Current time: 12:34)
# l2 (loss) on training is 0.005826231557875872
# snr on training is 16.670961380004883
# l2 (loss) on validation is 0.005051122512668371
# snr on validation is 17.528963088989258
#
# ------- EPOCH 136 RESULTS ------- (trained in 1.49 minutes. Current time: 12:36)
# l2 (loss) on training is 0.00580613361671567
# snr on training is 16.637535095214844
# l2 (loss) on validation is 0.005067316349595785
# snr on validation is 17.508459091186523
#
# ------- EPOCH 137 RESULTS ------- (trained in 1.5 minutes. Current time: 12:37)
# l2 (loss) on training is 0.005812809336930513
# snr on training is 16.63469123840332
# l2 (loss) on validation is 0.005047527141869068
# snr on validation is 17.53610610961914
#
# ------- EPOCH 138 RESULTS ------- (trained in 1.51 minutes. Current time: 12:39)
# l2 (loss) on training is 0.005822491366416216
# snr on training is 16.659353256225586
# l2 (loss) on validation is 0.005048723891377449
# snr on validation is 17.534025192260742
#
# ------- EPOCH 139 RESULTS ------- (trained in 1.5 minutes. Current time: 12:40)
# l2 (loss) on training is 0.005803362466394901
# snr on training is 16.6469783782959
# l2 (loss) on validation is 0.00506227882578969
# snr on validation is 17.516996383666992
#
# ------- EPOCH 140 RESULTS ------- (trained in 1.5 minutes. Current time: 12:42)
# l2 (loss) on training is 0.005799631588160992
# snr on training is 16.654706954956055
# l2 (loss) on validation is 0.005057180766016245
# snr on validation is 17.521944046020508
#
# ------- EPOCH 141 RESULTS ------- (trained in 1.51 minutes. Current time: 12:44)
# l2 (loss) on training is 0.005801222752779722
# snr on training is 16.647327423095703
# l2 (loss) on validation is 0.00505437608808279
# snr on validation is 17.527362823486328
#
# ------- EPOCH 142 RESULTS ------- (trained in 1.5 minutes. Current time: 12:45)
# l2 (loss) on training is 0.005798208061605692
# snr on training is 16.660398483276367
# l2 (loss) on validation is 0.005041544791311026
# snr on validation is 17.545480728149414
#
# ------- EPOCH 143 RESULTS ------- (trained in 1.5 minutes. Current time: 12:47)
# l2 (loss) on training is 0.005805224645882845
# snr on training is 16.654857635498047
# l2 (loss) on validation is 0.005051929969340563
# snr on validation is 17.53080177307129
#
# ------- EPOCH 144 RESULTS ------- (trained in 1.5 minutes. Current time: 12:48)
# l2 (loss) on training is 0.005799497477710247
# snr on training is 16.67420768737793
# l2 (loss) on validation is 0.005061272531747818
# snr on validation is 17.51900291442871
#
# ------- EPOCH 145 RESULTS ------- (trained in 1.5 minutes. Current time: 12:50)
# l2 (loss) on training is 0.005806530360132456
# snr on training is 16.64401626586914
# l2 (loss) on validation is 0.005049693863838911
# snr on validation is 17.53227996826172
#
# ------- EPOCH 146 RESULTS ------- (trained in 1.5 minutes. Current time: 12:51)
# l2 (loss) on training is 0.005780428182333708
# snr on training is 16.654582977294922
# l2 (loss) on validation is 0.005052835214883089
# snr on validation is 17.529813766479492
#
# ------- EPOCH 147 RESULTS ------- (trained in 1.5 minutes. Current time: 12:53)
# l2 (loss) on training is 0.005810917355120182
# snr on training is 16.66893196105957
# l2 (loss) on validation is 0.005049910396337509
# snr on validation is 17.533235549926758
#
# ------- EPOCH 148 RESULTS ------- (trained in 1.51 minutes. Current time: 12:54)
# l2 (loss) on training is 0.005798253230750561
# snr on training is 16.659391403198242
# l2 (loss) on validation is 0.005067234858870506
# snr on validation is 17.51045799255371
#
# ------- EPOCH 149 RESULTS ------- (trained in 1.51 minutes. Current time: 12:56)
# l2 (loss) on training is 0.005804426968097687
# snr on training is 16.670238494873047
# l2 (loss) on validation is 0.005047249142080545
# snr on validation is 17.536222457885742
#
# ------- EPOCH 150 RESULTS ------- (trained in 1.5 minutes. Current time: 12:57)
# l2 (loss) on training is 0.005789544899016619
# snr on training is 16.654359817504883
# l2 (loss) on validation is 0.00504011707380414
# snr on validation is 17.54425811767578
#
# ------- EPOCH 151 RESULTS ------- (trained in 1.5 minutes. Current time: 12:59)
# l2 (loss) on training is 0.005787270609289408
# snr on training is 16.672075271606445
# l2 (loss) on validation is 0.005049667786806822
# snr on validation is 17.533803939819336
#
# ------- EPOCH 152 RESULTS ------- (trained in 1.5 minutes. Current time: 13:00)
# l2 (loss) on training is 0.005807016976177692
# snr on training is 16.662593841552734
# l2 (loss) on validation is 0.005047448445111513
# snr on validation is 17.535844802856445
#
# ------- EPOCH 153 RESULTS ------- (trained in 1.5 minutes. Current time: 13:02)
# l2 (loss) on training is 0.005787528585642576
# snr on training is 16.683948516845703
# l2 (loss) on validation is 0.0050447555258870125
# snr on validation is 17.539480209350586
#
# ------- EPOCH 154 RESULTS ------- (trained in 1.5 minutes. Current time: 13:03)
# l2 (loss) on training is 0.005806001368910074
# snr on training is 16.655460357666016
# l2 (loss) on validation is 0.005056120455265045
# snr on validation is 17.522417068481445
#
# ------- EPOCH 155 RESULTS ------- (trained in 1.5 minutes. Current time: 13:05)
# l2 (loss) on training is 0.005784583278000355
# snr on training is 16.6651611328125
# l2 (loss) on validation is 0.005038822069764137
# snr on validation is 17.546794891357422
#
# ------- EPOCH 156 RESULTS ------- (trained in 1.5 minutes. Current time: 13:06)
# l2 (loss) on training is 0.0057916720397770405
# snr on training is 16.67359733581543
# l2 (loss) on validation is 0.005058616865426302
# snr on validation is 17.51864242553711
#
# ------- EPOCH 157 RESULTS ------- (trained in 1.5 minutes. Current time: 13:08)
# l2 (loss) on training is 0.005788629874587059
# snr on training is 16.667762756347656
# l2 (loss) on validation is 0.005048134829849005
# snr on validation is 17.531774520874023
#
# ------- EPOCH 158 RESULTS ------- (trained in 1.51 minutes. Current time: 13:09)
# l2 (loss) on training is 0.005785462912172079
# snr on training is 16.696643829345703
# l2 (loss) on validation is 0.0050460887141525745
# snr on validation is 17.534564971923828
#
# ------- EPOCH 159 RESULTS ------- (trained in 1.5 minutes. Current time: 13:11)
# l2 (loss) on training is 0.005777806043624878
# snr on training is 16.67626190185547
# l2 (loss) on validation is 0.0050533791072666645
# snr on validation is 17.5291805267334
#
# ------- EPOCH 160 RESULTS ------- (trained in 1.5 minutes. Current time: 13:13)
# l2 (loss) on training is 0.005780585575848818
# snr on training is 16.678255081176758
# l2 (loss) on validation is 0.0050468179397284985
# snr on validation is 17.539152145385742
#
# ------- EPOCH 161 RESULTS ------- (trained in 1.51 minutes. Current time: 13:14)
# l2 (loss) on training is 0.005772335454821587
# snr on training is 16.690370559692383
# l2 (loss) on validation is 0.005051757674664259
# snr on validation is 17.531091690063477
#
# ------- EPOCH 162 RESULTS ------- (trained in 1.51 minutes. Current time: 13:16)
# l2 (loss) on training is 0.0057822829112410545
# snr on training is 16.676408767700195
# l2 (loss) on validation is 0.005067505408078432
# snr on validation is 17.509321212768555
#
# ------- EPOCH 163 RESULTS ------- (trained in 1.5 minutes. Current time: 13:17)
# l2 (loss) on training is 0.005769841838628054
# snr on training is 16.67617416381836
# l2 (loss) on validation is 0.0050653559155762196
# snr on validation is 17.511701583862305
#
# ------- EPOCH 164 RESULTS ------- (trained in 1.51 minutes. Current time: 13:19)
# l2 (loss) on training is 0.005804389715194702
# snr on training is 16.687679290771484
# l2 (loss) on validation is 0.005058107431977987
# snr on validation is 17.518980026245117
#
# ------- EPOCH 165 RESULTS ------- (trained in 1.51 minutes. Current time: 13:20)
# l2 (loss) on training is 0.005793608259409666
# snr on training is 16.689529418945312
# l2 (loss) on validation is 0.005057381931692362
# snr on validation is 17.52271270751953
#
# ------- EPOCH 166 RESULTS ------- (trained in 1.51 minutes. Current time: 13:22)
# l2 (loss) on training is 0.005765134934335947
# snr on training is 16.6790714263916
# l2 (loss) on validation is 0.0050632543861866
# snr on validation is 17.513368606567383
#
# ------- EPOCH 167 RESULTS ------- (trained in 1.51 minutes. Current time: 13:23)
# l2 (loss) on training is 0.005782015156000853
# snr on training is 16.66547966003418
# l2 (loss) on validation is 0.005051082000136375
# snr on validation is 17.532548904418945
#
# ------- EPOCH 168 RESULTS ------- (trained in 1.51 minutes. Current time: 13:25)
# l2 (loss) on training is 0.005766304209828377
# snr on training is 16.704713821411133
# l2 (loss) on validation is 0.005050132051110268
# snr on validation is 17.53339958190918
#
# ------- EPOCH 169 RESULTS ------- (trained in 1.5 minutes. Current time: 13:26)
# l2 (loss) on training is 0.005769005976617336
# snr on training is 16.68021011352539
# l2 (loss) on validation is 0.005046807695180178
# snr on validation is 17.538116455078125
#
# ------- EPOCH 170 RESULTS ------- (trained in 1.5 minutes. Current time: 13:28)
# l2 (loss) on training is 0.005786053370684385
# snr on training is 16.6937198638916
# l2 (loss) on validation is 0.005054749548435211
# snr on validation is 17.524765014648438
#
# ------- EPOCH 171 RESULTS ------- (trained in 1.5 minutes. Current time: 13:29)
# l2 (loss) on training is 0.005780096165835857
# snr on training is 16.70207977294922
# l2 (loss) on validation is 0.00506189139559865
# snr on validation is 17.514135360717773
#
# ------- EPOCH 172 RESULTS ------- (trained in 1.51 minutes. Current time: 13:31)
# l2 (loss) on training is 0.005763955879956484
# snr on training is 16.69245719909668
# l2 (loss) on validation is 0.005053545348346233
# snr on validation is 17.523483276367188
#
# ------- EPOCH 173 RESULTS ------- (trained in 1.5 minutes. Current time: 13:32)
# l2 (loss) on training is 0.00577825540676713
# snr on training is 16.69866943359375
# l2 (loss) on validation is 0.005042097065597773
# snr on validation is 17.54213523864746
#
# ------- EPOCH 174 RESULTS ------- (trained in 1.5 minutes. Current time: 13:34)
# l2 (loss) on training is 0.005757699720561504
# snr on training is 16.679628372192383
# l2 (loss) on validation is 0.005036960821598768
# snr on validation is 17.548355102539062
#
# ------- EPOCH 175 RESULTS ------- (trained in 1.52 minutes. Current time: 13:36)
# l2 (loss) on training is 0.005767902359366417
# snr on training is 16.693843841552734
# l2 (loss) on validation is 0.005046382546424866
# snr on validation is 17.53731918334961
#
# ------- EPOCH 176 RESULTS ------- (trained in 1.51 minutes. Current time: 13:37)
# l2 (loss) on training is 0.005757535807788372
# snr on training is 16.717954635620117
# l2 (loss) on validation is 0.0050528631545603275
# snr on validation is 17.528057098388672
#
# ------- EPOCH 177 RESULTS ------- (trained in 1.51 minutes. Current time: 13:39)
# l2 (loss) on training is 0.005789660383015871
# snr on training is 16.683761596679688
# l2 (loss) on validation is 0.005055595654994249
# snr on validation is 17.524625778198242
#
# ------- EPOCH 178 RESULTS ------- (trained in 1.5 minutes. Current time: 13:40)
# l2 (loss) on training is 0.005745612550526857
# snr on training is 16.70143699645996
# l2 (loss) on validation is 0.005053464323282242
# snr on validation is 17.52592658996582
#
# ------- EPOCH 179 RESULTS ------- (trained in 1.51 minutes. Current time: 13:42)
# l2 (loss) on training is 0.005762252490967512
# snr on training is 16.710407257080078
# l2 (loss) on validation is 0.005049033090472221
# snr on validation is 17.53276824951172
#
# ------- EPOCH 180 RESULTS ------- (trained in 1.51 minutes. Current time: 13:43)
# l2 (loss) on training is 0.005792285781353712
# snr on training is 16.682151794433594
# l2 (loss) on validation is 0.005044113378971815
# snr on validation is 17.541837692260742
#
# ------- EPOCH 181 RESULTS ------- (trained in 1.51 minutes. Current time: 13:45)
# l2 (loss) on training is 0.0057551804929971695
# snr on training is 16.682538986206055
# l2 (loss) on validation is 0.005074551794677973
# snr on validation is 17.499980926513672
#
# ------- EPOCH 182 RESULTS ------- (trained in 1.51 minutes. Current time: 13:46)
# l2 (loss) on training is 0.005787407048046589
# snr on training is 16.715290069580078
# l2 (loss) on validation is 0.005063701421022415
# snr on validation is 17.5131893157959
#
# ------- EPOCH 183 RESULTS ------- (trained in 1.51 minutes. Current time: 13:48)
# l2 (loss) on training is 0.005747942253947258
# snr on training is 16.702241897583008
# l2 (loss) on validation is 0.005057176109403372
# snr on validation is 17.52028465270996
#
# ------- EPOCH 184 RESULTS ------- (trained in 1.5 minutes. Current time: 13:49)
# l2 (loss) on training is 0.00574555154889822
# snr on training is 16.70035171508789
# l2 (loss) on validation is 0.005041030701249838
# snr on validation is 17.543004989624023
#
# ------- EPOCH 185 RESULTS ------- (trained in 1.51 minutes. Current time: 13:51)
# l2 (loss) on training is 0.005767888389527798
# snr on training is 16.711071014404297
# l2 (loss) on validation is 0.00504554295912385
# snr on validation is 17.537317276000977
#
# ------- EPOCH 186 RESULTS ------- (trained in 1.51 minutes. Current time: 13:52)
# l2 (loss) on training is 0.0057443552650511265
# snr on training is 16.71064567565918
# l2 (loss) on validation is 0.005043495912104845
# snr on validation is 17.541746139526367
#
# ------- EPOCH 187 RESULTS ------- (trained in 1.51 minutes. Current time: 13:54)
# l2 (loss) on training is 0.005769361276179552
# snr on training is 16.723026275634766
# l2 (loss) on validation is 0.005045605357736349
# snr on validation is 17.539106369018555
#
# ------- EPOCH 188 RESULTS ------- (trained in 1.51 minutes. Current time: 13:55)
# l2 (loss) on training is 0.005744136404246092
# snr on training is 16.698619842529297
# l2 (loss) on validation is 0.005064066965132952
# snr on validation is 17.51380729675293
#
# ------- EPOCH 189 RESULTS ------- (trained in 1.52 minutes. Current time: 13:57)
# l2 (loss) on training is 0.005752858705818653
# snr on training is 16.73145866394043
# l2 (loss) on validation is 0.005051381420344114
# snr on validation is 17.533769607543945
#
# ------- EPOCH 190 RESULTS ------- (trained in 1.5 minutes. Current time: 13:59)
# l2 (loss) on training is 0.005759004969149828
# snr on training is 16.721891403198242
# l2 (loss) on validation is 0.00504928408190608
# snr on validation is 17.53318977355957
#
# ------- EPOCH 191 RESULTS ------- (trained in 1.5 minutes. Current time: 14:00)
# l2 (loss) on training is 0.0057358997873961926
# snr on training is 16.719947814941406
# l2 (loss) on validation is 0.005041791591793299
# snr on validation is 17.542219161987305
#
# ------- EPOCH 192 RESULTS ------- (trained in 1.51 minutes. Current time: 14:02)
# l2 (loss) on training is 0.00574977183714509
# snr on training is 16.703947067260742
# l2 (loss) on validation is 0.005053867120295763
# snr on validation is 17.52643394470215
#
# ------- EPOCH 193 RESULTS ------- (trained in 1.5 minutes. Current time: 14:03)
# l2 (loss) on training is 0.00574814947322011
# snr on training is 16.72543716430664
# l2 (loss) on validation is 0.005055970512330532
# snr on validation is 17.522825241088867
#
# ------- EPOCH 194 RESULTS ------- (trained in 1.51 minutes. Current time: 14:05)
# l2 (loss) on training is 0.0057381680235266685
# snr on training is 16.724119186401367
# l2 (loss) on validation is 0.00504703214392066
# snr on validation is 17.538593292236328
#
# ------- EPOCH 195 RESULTS ------- (trained in 1.51 minutes. Current time: 14:06)
# l2 (loss) on training is 0.005755760706961155
# snr on training is 16.725629806518555
# l2 (loss) on validation is 0.00505349226295948
# snr on validation is 17.527189254760742
#
# ------- EPOCH 196 RESULTS ------- (trained in 1.52 minutes. Current time: 14:08)
# l2 (loss) on training is 0.005725800059735775
# snr on training is 16.72477912902832
# l2 (loss) on validation is 0.005042138043791056
# snr on validation is 17.538938522338867
#
# ------- EPOCH 197 RESULTS ------- (trained in 1.52 minutes. Current time: 14:09)
# l2 (loss) on training is 0.0057497574016451836
# snr on training is 16.721590042114258
# l2 (loss) on validation is 0.005055293906480074
# snr on validation is 17.524904251098633
#
# ------- EPOCH 198 RESULTS ------- (trained in 1.52 minutes. Current time: 14:11)
# l2 (loss) on training is 0.00573738943785429
# snr on training is 16.732084274291992
# l2 (loss) on validation is 0.005049168597906828
# snr on validation is 17.53129768371582
#
# ------- EPOCH 199 RESULTS ------- (trained in 1.53 minutes. Current time: 14:12)
# l2 (loss) on training is 0.005757400766015053
# snr on training is 16.735950469970703
# l2 (loss) on validation is 0.005049580708146095
# snr on validation is 17.53173065185547
#
# ------- EPOCH 200 RESULTS ------- (trained in 1.53 minutes. Current time: 14:14)
# l2 (loss) on training is 0.005729490891098976
# snr on training is 16.738872528076172
# l2 (loss) on validation is 0.005045175086706877
# snr on validation is 17.54113006591797
#
# ------- EPOCH 201 RESULTS ------- (trained in 1.53 minutes. Current time: 14:16)
# l2 (loss) on training is 0.005721799563616514
# snr on training is 16.715938568115234
# l2 (loss) on validation is 0.005048905964940786
# snr on validation is 17.53406524658203
#
# ------- EPOCH 202 RESULTS ------- (trained in 1.53 minutes. Current time: 14:17)
# l2 (loss) on training is 0.005759366787970066
# snr on training is 16.735397338867188
# l2 (loss) on validation is 0.005039501469582319
# snr on validation is 17.54796600341797
#
# ------- EPOCH 203 RESULTS ------- (trained in 1.52 minutes. Current time: 14:19)
# l2 (loss) on training is 0.005747333634644747
# snr on training is 16.717296600341797
# l2 (loss) on validation is 0.005035041831433773
# snr on validation is 17.553878784179688
#
# ------- EPOCH 204 RESULTS ------- (trained in 1.53 minutes. Current time: 14:20)
# l2 (loss) on training is 0.005737175699323416
# snr on training is 16.731239318847656
# l2 (loss) on validation is 0.005057694856077433
# snr on validation is 17.52166748046875
#
# ------- EPOCH 205 RESULTS ------- (trained in 1.54 minutes. Current time: 14:22)
# l2 (loss) on training is 0.0057561155408620834
# snr on training is 16.72091293334961
# l2 (loss) on validation is 0.005079513415694237
# snr on validation is 17.492399215698242
#
# ------- EPOCH 206 RESULTS ------- (trained in 1.53 minutes. Current time: 14:23)
# l2 (loss) on training is 0.005748842842876911
# snr on training is 16.737133026123047
# l2 (loss) on validation is 0.005044527817517519
# snr on validation is 17.540956497192383
#
# ------- EPOCH 207 RESULTS ------- (trained in 1.53 minutes. Current time: 14:25)
# l2 (loss) on training is 0.005740522872656584
# snr on training is 16.71420669555664
# l2 (loss) on validation is 0.005040263757109642
# snr on validation is 17.546995162963867
#
# ------- EPOCH 208 RESULTS ------- (trained in 1.52 minutes. Current time: 14:26)
# l2 (loss) on training is 0.005729894153773785
# snr on training is 16.717723846435547
# l2 (loss) on validation is 0.005064099095761776
# snr on validation is 17.513322830200195
#
# ------- EPOCH 209 RESULTS ------- (trained in 1.53 minutes. Current time: 14:28)
# l2 (loss) on training is 0.005723237060010433
# snr on training is 16.73647689819336
# l2 (loss) on validation is 0.005062629468739033
# snr on validation is 17.511083602905273
#
# ------- EPOCH 210 RESULTS ------- (trained in 1.52 minutes. Current time: 14:30)
# l2 (loss) on training is 0.0057310741394758224
# snr on training is 16.75522804260254
# l2 (loss) on validation is 0.005062973592430353
# snr on validation is 17.507400512695312
#
# ------- EPOCH 211 RESULTS ------- (trained in 1.53 minutes. Current time: 14:31)
# l2 (loss) on training is 0.0057551199570298195
# snr on training is 16.731704711914062
# l2 (loss) on validation is 0.005043744575232267
# snr on validation is 17.53650665283203
#
# ------- EPOCH 212 RESULTS ------- (trained in 1.54 minutes. Current time: 14:33)
# l2 (loss) on training is 0.005751026328653097
# snr on training is 16.737133026123047
# l2 (loss) on validation is 0.005042843520641327
# snr on validation is 17.545034408569336
#
# ------- EPOCH 213 RESULTS ------- (trained in 1.53 minutes. Current time: 14:34)
# l2 (loss) on training is 0.005729059688746929
# snr on training is 16.746152877807617
# l2 (loss) on validation is 0.005056311842054129
# snr on validation is 17.522802352905273
#
# ------- EPOCH 214 RESULTS ------- (trained in 1.52 minutes. Current time: 14:36)
# l2 (loss) on training is 0.005723919253796339
# snr on training is 16.74290657043457
# l2 (loss) on validation is 0.005048623774200678
# snr on validation is 17.529996871948242
#
# ------- EPOCH 215 RESULTS ------- (trained in 1.53 minutes. Current time: 14:37)
# l2 (loss) on training is 0.0057273143902421
# snr on training is 16.72171974182129
# l2 (loss) on validation is 0.005037559196352959
# snr on validation is 17.546037673950195
#
# ------- EPOCH 216 RESULTS ------- (trained in 1.53 minutes. Current time: 14:39)
# l2 (loss) on training is 0.005738375708460808
# snr on training is 16.75019645690918
# l2 (loss) on validation is 0.005037013906985521
# snr on validation is 17.54541015625
#
# ------- EPOCH 217 RESULTS ------- (trained in 1.53 minutes. Current time: 14:40)
# l2 (loss) on training is 0.0057194847613573074
# snr on training is 16.74632453918457
# l2 (loss) on validation is 0.005052352324128151
# snr on validation is 17.529687881469727
#
# ------- EPOCH 218 RESULTS ------- (trained in 1.53 minutes. Current time: 14:42)
# l2 (loss) on training is 0.005740019027143717
# snr on training is 16.731660842895508
# l2 (loss) on validation is 0.005052919965237379
# snr on validation is 17.52629280090332
#
# ------- EPOCH 219 RESULTS ------- (trained in 1.54 minutes. Current time: 14:44)
# l2 (loss) on training is 0.005710938014090061
# snr on training is 16.745054244995117
# l2 (loss) on validation is 0.005047977901995182
# snr on validation is 17.536298751831055
#
# ------- EPOCH 220 RESULTS ------- (trained in 1.53 minutes. Current time: 14:45)
# l2 (loss) on training is 0.005757099017500877
# snr on training is 16.763504028320312
# l2 (loss) on validation is 0.005043813027441502
# snr on validation is 17.537765502929688
#
# ------- EPOCH 221 RESULTS ------- (trained in 1.53 minutes. Current time: 14:47)
# l2 (loss) on training is 0.005716136656701565
# snr on training is 16.733686447143555
# l2 (loss) on validation is 0.005046073812991381
# snr on validation is 17.540016174316406
#
# ------- EPOCH 222 RESULTS ------- (trained in 1.53 minutes. Current time: 14:48)
# l2 (loss) on training is 0.0057106357999145985
# snr on training is 16.740394592285156
# l2 (loss) on validation is 0.005031094420701265
# snr on validation is 17.557315826416016
#
# ------- EPOCH 223 RESULTS ------- (trained in 1.53 minutes. Current time: 14:50)
# l2 (loss) on training is 0.005733348894864321
# snr on training is 16.75084114074707
# l2 (loss) on validation is 0.005036213900893927
# snr on validation is 17.54958152770996
#
# ------- EPOCH 224 RESULTS ------- (trained in 1.53 minutes. Current time: 14:51)
# l2 (loss) on training is 0.00571028608828783
# snr on training is 16.72245979309082
# l2 (loss) on validation is 0.0050562587566673756
# snr on validation is 17.523191452026367
#
# ------- EPOCH 225 RESULTS ------- (trained in 1.53 minutes. Current time: 14:53)
# l2 (loss) on training is 0.0057273427955806255
# snr on training is 16.765600204467773
# l2 (loss) on validation is 0.005044805817306042
# snr on validation is 17.5374698638916
#
# ------- EPOCH 226 RESULTS ------- (trained in 1.53 minutes. Current time: 14:54)
# l2 (loss) on training is 0.005724117625504732
# snr on training is 16.77503776550293
# l2 (loss) on validation is 0.005044776480644941
# snr on validation is 17.535743713378906
#
# ------- EPOCH 227 RESULTS ------- (trained in 1.53 minutes. Current time: 14:56)
# l2 (loss) on training is 0.005727074574679136
# snr on training is 16.737491607666016
# l2 (loss) on validation is 0.005045255646109581
# snr on validation is 17.5411376953125
#
# ------- EPOCH 228 RESULTS ------- (trained in 1.53 minutes. Current time: 14:58)
# l2 (loss) on training is 0.005712037440389395
# snr on training is 16.769330978393555
# l2 (loss) on validation is 0.005043589975684881
# snr on validation is 17.538415908813477
#
# ------- EPOCH 229 RESULTS ------- (trained in 1.53 minutes. Current time: 14:59)
# l2 (loss) on training is 0.005723171401768923
# snr on training is 16.754667282104492
# l2 (loss) on validation is 0.005055752117186785
# snr on validation is 17.524158477783203
#
# ------- EPOCH 230 RESULTS ------- (trained in 1.53 minutes. Current time: 15:01)
# l2 (loss) on training is 0.005704880692064762
# snr on training is 16.741233825683594
# l2 (loss) on validation is 0.005050059873610735
# snr on validation is 17.531787872314453
#
# ------- EPOCH 231 RESULTS ------- (trained in 1.53 minutes. Current time: 15:02)
# l2 (loss) on training is 0.005705974530428648
# snr on training is 16.784950256347656
# l2 (loss) on validation is 0.0050548347644507885
# snr on validation is 17.525400161743164
#
# ------- EPOCH 232 RESULTS ------- (trained in 1.53 minutes. Current time: 15:04)
# l2 (loss) on training is 0.005708639044314623
# snr on training is 16.748737335205078
# l2 (loss) on validation is 0.005054466892033815
# snr on validation is 17.521793365478516
#
# ------- EPOCH 233 RESULTS ------- (trained in 1.52 minutes. Current time: 15:05)
# l2 (loss) on training is 0.005732421297580004
# snr on training is 16.738574981689453
# l2 (loss) on validation is 0.005045927595347166
# snr on validation is 17.53610610961914
#
# ------- EPOCH 234 RESULTS ------- (trained in 1.52 minutes. Current time: 15:07)
# l2 (loss) on training is 0.005714297294616699
# snr on training is 16.786808013916016
# l2 (loss) on validation is 0.005041531752794981
# snr on validation is 17.54608726501465
#
# ------- EPOCH 235 RESULTS ------- (trained in 1.53 minutes. Current time: 15:08)
# l2 (loss) on training is 0.00573691027238965
# snr on training is 16.759756088256836
# l2 (loss) on validation is 0.0050456225872039795
# snr on validation is 17.539106369018555
#
# ------- EPOCH 236 RESULTS ------- (trained in 1.52 minutes. Current time: 15:10)
# l2 (loss) on training is 0.005707459524273872
# snr on training is 16.743511199951172
# l2 (loss) on validation is 0.005044524557888508
# snr on validation is 17.53977394104004
#
# ------- EPOCH 237 RESULTS ------- (trained in 1.53 minutes. Current time: 15:12)
# l2 (loss) on training is 0.005721945781260729
# snr on training is 16.795007705688477
# l2 (loss) on validation is 0.005049094092100859
# snr on validation is 17.532455444335938
#
# ------- EPOCH 238 RESULTS ------- (trained in 1.53 minutes. Current time: 15:13)
# l2 (loss) on training is 0.005665445700287819
# snr on training is 16.735416412353516
# l2 (loss) on validation is 0.005054753739386797
# snr on validation is 17.52567481994629
#
# ------- EPOCH 239 RESULTS ------- (trained in 1.54 minutes. Current time: 15:15)
# l2 (loss) on training is 0.005710355471819639
# snr on training is 16.784927368164062
# l2 (loss) on validation is 0.005044674500823021
# snr on validation is 17.53914451599121
#
# ------- EPOCH 240 RESULTS ------- (trained in 1.53 minutes. Current time: 15:16)
# l2 (loss) on training is 0.0057160984724760056
# snr on training is 16.77682113647461
# l2 (loss) on validation is 0.005044931545853615
# snr on validation is 17.537683486938477
#
# ------- EPOCH 241 RESULTS ------- (trained in 1.52 minutes. Current time: 15:18)
# l2 (loss) on training is 0.005709666293114424
# snr on training is 16.752952575683594
# l2 (loss) on validation is 0.005044270772486925
# snr on validation is 17.53569984436035
#
# ------- EPOCH 242 RESULTS ------- (trained in 1.53 minutes. Current time: 15:19)
# l2 (loss) on training is 0.005715002305805683
# snr on training is 16.76174545288086
# l2 (loss) on validation is 0.005047864280641079
# snr on validation is 17.533708572387695
#
# ------- EPOCH 243 RESULTS ------- (trained in 1.52 minutes. Current time: 15:21)
# l2 (loss) on training is 0.005704755429178476
# snr on training is 16.779930114746094
# l2 (loss) on validation is 0.005048785358667374
# snr on validation is 17.534828186035156
#
# ------- EPOCH 244 RESULTS ------- (trained in 1.53 minutes. Current time: 15:22)
# l2 (loss) on training is 0.005693044047802687
# snr on training is 16.750123977661133
# l2 (loss) on validation is 0.005046804901212454
# snr on validation is 17.535503387451172
#
# ------- EPOCH 245 RESULTS ------- (trained in 1.53 minutes. Current time: 15:24)
# l2 (loss) on training is 0.005696076434105635
# snr on training is 16.800859451293945
# l2 (loss) on validation is 0.005050752777606249
# snr on validation is 17.53127098083496
#
# ------- EPOCH 246 RESULTS ------- (trained in 1.53 minutes. Current time: 15:26)
# l2 (loss) on training is 0.005728369113057852
# snr on training is 16.769474029541016
# l2 (loss) on validation is 0.005043053068220615
# snr on validation is 17.53711700439453
